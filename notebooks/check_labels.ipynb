# %%
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
import os

# %%
project_root = Path(os.getcwd()).parent
labels_dir = project_root / 'data/processed/valid/labels'
print(str(labels_dir))
# Out:
# /Users/mitchweikert/Documents/random_projects/spacenet/data/processed/valid/labels

# %%
filename='labels_1_13_78.npy'

# %%
labels = np.load(labels_dir / filename)

# %%
plt.imshow(labels[0, :, :])
